# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
#Loading the Dataset
data=pd.read_csv('C:/Users/USER/OneDrive/Desktop/ICT/Datas/Sales_data_zone_wise.csv')

# %%
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %% [markdown]
# # The mean sales generated by each zone.

# %%
data.mean(numeric_only=True)
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# Zone - D    1.842927e+06
# dtype: float64

# %% [markdown]
# # Total sales generated by all the zones for each month.

# %%
data["Total_Sales"]=data.sum(axis=1,numeric_only=True)

# %%
data[['Month','Total_Sales']]
# Out:
#          Month  Total_Sales
# 0    Month - 1      7022544
# 1    Month - 2      7152303
# 2    Month - 3      6475939
# 3    Month - 4      8174449
# 4    Month - 5      5995328
# 5    Month - 6      7151387
# 6    Month - 7      7287108
# 7    Month - 8      7816299
# 8    Month - 9      6703395
# 9   Month - 10      7128210
# 10  Month - 11      7032783
# 11  Month - 12      6111084
# 12  Month - 13      5925424
# 13  Month - 14      7155515
# 14  Month - 15      5934156
# 15  Month - 16      6506659
# 16  Month - 17      7149383
# 17  Month - 18      7083490
# 18  Month - 19      6971953
# 19  Month - 20      7124599
# 20  Month - 21      7389597
# 21  Month - 22      7560001
# 22  Month - 23      6687919
# 23  Month - 24      7784747
# 24  Month - 25      6095918
# 25  Month - 26      6512360
# 26  Month - 27      6267918
# 27  Month - 28      7470920
# 28  Month - 29      6772277

# %% [markdown]
# # Check whether all the zones generate the same amount of sales.

# %% [markdown]
# Here we've to compare more than two means, therefore we use a one-way ANOVA test.

# %%
#Null hypothesis: All the zones generate the same amount of sales;H0: μ1=μ2=μ3=μ4
#Alternative hypothesis: At least, one zone sale is different;H1: All μ are not equal

# %%
#calculating F-statistic and p-value
fvalue, pvalue = stats.f_oneway(data['Zone - A'], data['Zone - B'], data['Zone - C'], data['Zone - D'])

# %%
print(fvalue, pvalue)
# Out:
# 5.672056106843581 0.0011827601694503335

# %%
#Degrees of Freedom

# %% [markdown]
# No.of groups, k = 4
# DoF between = k-1 = 4-1 = 3
# Total no.of samples in all groups,n = 116
# DoF within = n-k = 116-4 = 112

# %%
#calculating F-crtic
f_critic=stats.f.ppf(1-0.05,3,112)
f_critic
# Out:
# 2.6856434512366034

# %%
#Hypothesis Testing

# %%
if(fvalue>f_critic and pvalue<0.05):
    print('We reject the null hypothesis. That is, zone-wise sales are not same.')
else:
    print('We failto reject the null hypothesis. That is, all the zones generate the same amount of sales.')
# Out:
# We reject the null hypothesis. That is, zone-wise sales are not same.
